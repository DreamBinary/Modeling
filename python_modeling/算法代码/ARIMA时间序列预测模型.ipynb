# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import numpy as np

pio.templates.default = "plotly_white"

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.graphics.api import qqplot

# %%
data = [10930, 10318, 10595, 10972, 7706, 6756, 9092, 10551, 9722, 10913, 11151, 8186, 6422,
        6337, 11649, 11652, 10310, 12043, 7937, 6476, 9662, 9570, 9981, 9331, 9449, 6773, 6304, 9355, 10477, 10148,
        10395, 11261, 8713, 7299, 10424, 10795, 11069, 11602, 11427, 9095, 7707, 10767, 12136, 12812, 12006, 12528,
        10329, 7818, 11719, 11683, 12603, 11495, 13670, 11337, 10232, 13261, 13230, 15535, 16837, 19598, 14823, 11622,
        19391, 18177, 19994, 14723, 15694, 13248, 9543, 12872, 13101, 15053, 12619, 13749, 10228, 9725, 14729, 12518,
        14564, 15085, 14722, 11999, 9390, 13481, 14795, 15845, 15271, 14686, 11054, 10395]
data = np.array(data, dtype=np.float64)

# %%
data = pd.Series(data)
data.index = pd.Index(np.arange(1900, 1990))
data
# Out:
# 1900    10930.0
# 1901    10318.0
# 1902    10595.0
# 1903    10972.0
# 1904     7706.0
#          ...
# 1985    15845.0
# 1986    15271.0
# 1987    14686.0
# 1988    11054.0
# 1989    10395.0
# Length: 90, dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
