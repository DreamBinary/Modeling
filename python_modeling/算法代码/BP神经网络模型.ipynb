# %%
import numpy as np
import math
import random
import string
import plotly.express as px

# %%
#生成区间[a,b]内的随机数
def random_number(a, b):
    return (b - a) * random.random() + a

# %%
#生成一个矩阵，大小为m*n,并且设置默认零矩阵
def makematrix(m, n, fill=0.0):
    a = []
    for i in range(m):
        a.append([fill] * n)
    return a

# %%
#函数sigmoid(),这里采用tanh，因为看起来要比标准的sigmoid函数好看
def sigmoid(x):
    return math.tanh(x)

# %%
#函数sigmoid的派生函数
def derived_sigmoid(x):
    return 1.0 - x ** 2

# %%
#构造三层BP网络架构
class BPNN:
    def __init__(self, num_in, num_hidden, num_out):
        #输入层，隐藏层，输出层的节点数
        self.num_in = num_in + 1  #增加一个偏置结点
        self.num_hidden = num_hidden + 1  #增加一个偏置结点
        self.num_out = num_out

        #激活神经网络的所有节点（向量）
        self.active_in = [1.0] * self.num_in
        self.active_hidden = [1.0] * self.num_hidden
        self.active_out = [1.0] * self.num_out

        #创建权重矩阵
        self.wight_in = makematrix(self.num_in, self.num_hidden)
        self.wight_out = makematrix(self.num_hidden, self.num_out)

        #对权值矩阵赋初值
        for i in range(self.num_in):
            for j in range(self.num_hidden):
                self.wight_in[i][j] = random_number(-0.2, 0.2)
        for i in range(self.num_hidden):
            for j in range(self.num_out):
                self.wight_out[i][j] = random_number(-0.2, 0.2)

        #最后建立动量因子（矩阵）
        self.ci = makematrix(self.num_in, self.num_hidden)
        self.co = makematrix(self.num_hidden, self.num_out)

        #信号正向传播

    def update(self, inputs):
        if len(inputs) != self.num_in - 1:
            raise ValueError('与输入层节点数不符')

        #数据输入输入层
        for i in range(self.num_in - 1):
            #self.active_in[i] = sigmoid(inputs[i])  #或者先在输入层进行数据处理
            self.active_in[i] = inputs[i]  #active_in[]是输入数据的矩阵

        #数据在隐藏层的处理
        for i in range(self.num_hidden - 1):
            sum = 0.0
            for j in range(self.num_in):
                sum = sum + self.active_in[i] * self.wight_in[j][i]
            self.active_hidden[i] = sigmoid(sum)  #active_hidden[]是处理完输入数据之后存储，作为输出层的输入数据

        #数据在输出层的处理
        for i in range(self.num_out):
            sum = 0.0
            for j in range(self.num_hidden):
                sum = sum + self.active_hidden[j] * self.wight_out[j][i]
            self.active_out[i] = sigmoid(sum)  #与上同理

        return self.active_out[:]

    #误差反向传播
    def errorbackpropagate(self, targets, lr, m):  #lr是学习率， m是动量因子
        if len(targets) != self.num_out:
            raise ValueError('与输出层节点数不符！')

        #首先计算输出层的误差
        out_deltas = [0.0] * self.num_out
        for i in range(self.num_out):
            error = targets[i] - self.active_out[i]
            out_deltas[i] = derived_sigmoid(self.active_out[i]) * error

        #然后计算隐藏层误差
        hidden_deltas = [0.0] * self.num_hidden
        for i in range(self.num_hidden):
            error = 0.0
            for j in range(self.num_out):
                error = error + out_deltas[j] * self.wight_out[i][j]
            hidden_deltas[i] = derived_sigmoid(self.active_hidden[i]) * error

        #首先更新输出层权值
        for i in range(self.num_hidden):
            for j in range(self.num_out):
                change = out_deltas[j] * self.active_hidden[i]
                self.wight_out[i][j] = self.wight_out[i][j] + lr * change + m * self.co[i][j]
                self.co[i][j] = change

        #然后更新输入层权值
        for i in range(self.num_in):
            for i in range(self.num_hidden):
                change = hidden_deltas[j] * self.active_in[i]
                self.wight_in[i][j] = self.wight_in[i][j] + lr * change + m * self.ci[i][j]
                self.ci[i][j] = change

        #计算总误差
        error = 0.0
        for i in range(len(targets)):
            error = error + 0.5 * (targets[i] - self.active_out[i]) ** 2
        return error

    #测试
    def test(self, patterns):
        for i in patterns:
            print(i[0], '->', self.update(i[0]))

    #权重
    def weights(self):
        print("输入层权重")
        for i in range(self.num_in):
            print(self.wight_in[i])
        print("输出层权重")
        for i in range(self.num_hidden):
            print(self.wight_out[i])

    def train(self, pattern, itera=100000, lr=0.1, m=0.1):
        for i in range(itera):
            error = 0.0
            for j in pattern:
                inputs = j[0]
                targets = j[1]
                self.update(inputs)
                error = error + self.errorbackpropagate(targets, lr, m)
            if i % 100 == 0:
                print('误差 %-.5f' % error)

# %%
#实例
def demo():
    patt = [
        [[1, 2, 5], [0]],
        [[1, 3, 4], [1]],
        [[1, 6, 2], [1]],
        [[1, 5, 1], [0]],
        [[1, 8, 4], [1]]
    ]
    #创建神经网络，3个输入节点，3个隐藏层节点，1个输出层节点
    n = BPNN(3, 3, 1)
    #训练神经网络
    n.train(patt)
    #测试神经网络
    n.test(patt)
    #查阅权重值
    n.weights()


demo()
# Out:
# 误差 1.05322
# 误差 0.48497
# 误差 0.41198
# 误差 0.35248
# 误差 0.30398
# 误差 0.26426
# 误差 0.23155
# 误差 0.20445
# 误差 0.18184
# 误差 0.16287
# 误差 0.14683
# 误差 0.13317
# 误差 0.12147
# 误差 0.11136
# 误差 0.10259
# 误差 0.09492
# 误差 0.08818
# 误差 0.08222
# 误差 0.07693
# 误差 0.07220
# 误差 0.06796
# 误差 0.06414
# 误差 0.06069
# 误差 0.05755
# 误差 0.05469
# 误差 0.05208
# 误差 0.04968
# 误差 0.04748
# 误差 0.04544
# 误差 0.04356
# 误差 0.04182
# 误差 0.04020
# 误差 0.03869
# 误差 0.03729
# 误差 0.03597
# 误差 0.03474
# 误差 0.03358
# 误差 0.03249
# 误差 0.03147
# 误差 0.03050
# 误差 0.02959
# 误差 0.02873
# 误差 0.02791
# 误差 0.02714
# 误差 0.02640
# 误差 0.02570
# 误差 0.02504
# 误差 0.02441
# 误差 0.02380
# 误差 0.02323
# 误差 0.02268
# 误差 0.02215
# 误差 0.02164
# 误差 0.02116
# 误差 0.02070
# 误差 0.02026
# 误差 0.01983
# 误差 0.01942
# 误差 0.01903
# 误差 0.01865
# 误差 0.01828
# 误差 0.01793
# 误差 0.01759
# 误差 0.01726
# 误差 0.01695
# 误差 0.01664
# 误差 0.01635
# 误差 0.01606
# 误差 0.01579
# 误差 0.01552
# 误差 0.01526
# 误差 0.01501
# 误差 0.01477
# 误差 0.01454
# 误差 0.01431
# 误差 0.01409
# 误差 0.01387
# 误差 0.01366
# 误差 0.01346
# 误差 0.01327
# 误差 0.01307
# 误差 0.01289
# 误差 0.01271
# 误差 0.01253
# 误差 0.01236
# 误差 0.01219
# 误差 0.01203
# 误差 0.01187
# 误差 0.01171
# 误差 0.01156
# 误差 0.01142
# 误差 0.01127
# 误差 0.01113
# 误差 0.01099
# 误差 0.01086
# 误差 0.01073
# 误差 0.01060
# 误差 0.01048
# 误差 0.01036
# 误差 0.01024
# 误差 0.01012
# 误差 0.01001
# 误差 0.00989
# 误差 0.00979
# 误差 0.00968
# 误差 0.00957
# 误差 0.00947
# 误差 0.00937
# 误差 0.00927
# 误差 0.00918
# 误差 0.00908
# 误差 0.00899
# 误差 0.00890
# 误差 0.00881
# 误差 0.00872
# 误差 0.00864
# 误差 0.00855
# 误差 0.00847
# 误差 0.00839
# 误差 0.00831
# 误差 0.00823
# 误差 0.00815
# 误差 0.00808
# 误差 0.00801
# 误差 0.00793
# 误差 0.00786
# 误差 0.00779
# 误差 0.00772
# 误差 0.00765
# 误差 0.00759
# 误差 0.00752
# 误差 0.00746
# 误差 0.00739
# 误差 0.00733
# 误差 0.00727
# 误差 0.00721
# 误差 0.00715
# 误差 0.00709
# 误差 0.00704
# 误差 0.00698
# 误差 0.00692
# 误差 0.00687
# 误差 0.00681
# 误差 0.00676
# 误差 0.00671
# 误差 0.00666
# 误差 0.00661
# 误差 0.00656
# 误差 0.00651
# 误差 0.00646
# 误差 0.00641
# 误差 0.00636
# 误差 0.00632
# 误差 0.00627
# 误差 0.00623
# 误差 0.00618
# 误差 0.00614
# 误差 0.00609
# 误差 0.00605
# 误差 0.00601
# 误差 0.00597
# 误差 0.00593
# 误差 0.00589
# 误差 0.00585
# 误差 0.00581
# 误差 0.00577
# 误差 0.00573
# 误差 0.00569
# 误差 0.00565
# 误差 0.00562
# 误差 0.00558
# 误差 0.00554
# 误差 0.00551
# 误差 0.00547
# 误差 0.00544
# 误差 0.00540
# 误差 0.00537
# 误差 0.00534
# 误差 0.00530
# 误差 0.00527
# 误差 0.00524
# 误差 0.00521
# 误差 0.00518
# 误差 0.00514
# 误差 0.00511
# 误差 0.00508
# 误差 0.00505
# 误差 0.00502
# 误差 0.00499
# 误差 0.00497
# 误差 0.00494
# 误差 0.00491
# 误差 0.00488
# 误差 0.00485
# 误差 0.00483
# 误差 0.00480
# 误差 0.00477
# 误差 0.00474
# 误差 0.00472
# 误差 0.00469
# 误差 0.00467
# 误差 0.00464
# 误差 0.00462
# 误差 0.00459
# 误差 0.00457
# 误差 0.00454
# 误差 0.00452
# 误差 0.00449
# 误差 0.00447
# 误差 0.00445
# 误差 0.00442
# 误差 0.00440
# 误差 0.00438
# 误差 0.00436
# 误差 0.00433
# 误差 0.00431
# 误差 0.00429
# 误差 0.00427
# 误差 0.00425
# 误差 0.00423
# 误差 0.00421
# 误差 0.00418
# 误差 0.00416
# 误差 0.00414
# 误差 0.00412
# 误差 0.00410
# 误差 0.00408
# 误差 0.00406
# 误差 0.00404
# 误差 0.00403
# 误差 0.00401
# 误差 0.00399
# 误差 0.00397
# 误差 0.00395
# 误差 0.00393
# 误差 0.00391
# 误差 0.00390
# 误差 0.00388
# 误差 0.00386
# 误差 0.00384
# 误差 0.00383
# 误差 0.00381
# 误差 0.00379
# 误差 0.00377
# 误差 0.00376
# 误差 0.00374
# 误差 0.00372
# 误差 0.00371
# 误差 0.00369
# 误差 0.00368
# 误差 0.00366
# 误差 0.00364
# 误差 0.00363
# 误差 0.00361
# 误差 0.00360
# 误差 0.00358
# 误差 0.00357
# 误差 0.00355
# 误差 0.00354
# 误差 0.00352
# 误差 0.00351
# 误差 0.00349
# 误差 0.00348
# 误差 0.00346
# 误差 0.00345
# 误差 0.00344
# 误差 0.00342
# 误差 0.00341
# 误差 0.00339
# 误差 0.00338
# 误差 0.00337
# 误差 0.00335
# 误差 0.00334
# 误差 0.00333
# 误差 0.00331
# 误差 0.00330
# 误差 0.00329
# 误差 0.00328
# 误差 0.00326
# 误差 0.00325
# 误差 0.00324
# 误差 0.00323
# 误差 0.00321
# 误差 0.00320
# 误差 0.00319
# 误差 0.00318
# 误差 0.00316
# 误差 0.00315
# 误差 0.00314
# 误差 0.00313
# 误差 0.00312
# 误差 0.00311
# 误差 0.00309
# 误差 0.00308
# 误差 0.00307
# 误差 0.00306
# 误差 0.00305
# 误差 0.00304
# 误差 0.00303
# 误差 0.00302
# 误差 0.00301
# 误差 0.00299
# 误差 0.00298
# 误差 0.00297
# 误差 0.00296
# 误差 0.00295
# 误差 0.00294
# 误差 0.00293
# 误差 0.00292
# 误差 0.00291
# 误差 0.00290
# 误差 0.00289
# 误差 0.00288
# 误差 0.00287
# 误差 0.00286
# 误差 0.00285
# 误差 0.00284
# 误差 0.00283
# 误差 0.00282
# 误差 0.00281
# 误差 0.00280
# 误差 0.00280
# 误差 0.00279
# 误差 0.00278
# 误差 0.00277
# 误差 0.00276
# 误差 0.00275
# 误差 0.00274
# 误差 0.00273
# 误差 0.00272
# 误差 0.00271
# 误差 0.00270
# 误差 0.00270
# 误差 0.00269
# 误差 0.00268
# 误差 0.00267
# 误差 0.00266
# 误差 0.00265
# 误差 0.00264
# 误差 0.00264
# 误差 0.00263
# 误差 0.00262
# 误差 0.00261
# 误差 0.00260
# 误差 0.00260
# 误差 0.00259
# 误差 0.00258
# 误差 0.00257
# 误差 0.00256
# 误差 0.00256
# 误差 0.00255
# 误差 0.00254
# 误差 0.00253
# 误差 0.00252
# 误差 0.00252
# 误差 0.00251
# 误差 0.00250
# 误差 0.00249
# 误差 0.00249
# 误差 0.00248
# 误差 0.00247
# 误差 0.00247
# 误差 0.00246
# 误差 0.00245
# 误差 0.00244
# 误差 0.00244
# 误差 0.00243
# 误差 0.00242
# 误差 0.00242
# 误差 0.00241
# 误差 0.00240
# 误差 0.00239
# 误差 0.00239
# 误差 0.00238
# 误差 0.00237
# 误差 0.00237
# 误差 0.00236
# 误差 0.00235
# 误差 0.00235
# 误差 0.00234
# 误差 0.00233
# 误差 0.00233
# 误差 0.00232
# 误差 0.00231
# 误差 0.00231
# 误差 0.00230
# 误差 0.00230
# 误差 0.00229
# 误差 0.00228
# 误差 0.00228
# 误差 0.00227
# 误差 0.00226
# 误差 0.00226
# 误差 0.00225
# 误差 0.00225
# 误差 0.00224
# 误差 0.00223
# 误差 0.00223
# 误差 0.00222
# 误差 0.00222
# 误差 0.00221
# 误差 0.00220
# 误差 0.00220
# 误差 0.00219
# 误差 0.00219
# 误差 0.00218
# 误差 0.00218
# 误差 0.00217
# 误差 0.00216
# 误差 0.00216
# 误差 0.00215
# 误差 0.00215
# 误差 0.00214
# 误差 0.00214
# 误差 0.00213
# 误差 0.00213
# 误差 0.00212
# 误差 0.00211
# 误差 0.00211
# 误差 0.00210
# 误差 0.00210
# 误差 0.00209
# 误差 0.00209
# 误差 0.00208
# 误差 0.00208
# 误差 0.00207
# 误差 0.00207
# 误差 0.00206
# 误差 0.00206
# 误差 0.00205
# 误差 0.00205
# 误差 0.00204
# 误差 0.00204
# 误差 0.00203
# 误差 0.00203
# 误差 0.00202
# 误差 0.00202
# 误差 0.00201
# 误差 0.00201
# 误差 0.00200
# 误差 0.00200
# 误差 0.00199
# 误差 0.00199
# 误差 0.00198
# 误差 0.00198
# 误差 0.00197
# 误差 0.00197
# 误差 0.00196
# 误差 0.00196
# 误差 0.00196
# 误差 0.00195
# 误差 0.00195
# 误差 0.00194
# 误差 0.00194
# 误差 0.00193
# 误差 0.00193
# 误差 0.00192
# 误差 0.00192
# 误差 0.00191
# 误差 0.00191
# 误差 0.00191
# 误差 0.00190
# 误差 0.00190
# 误差 0.00189
# 误差 0.00189
# 误差 0.00188
# 误差 0.00188
# 误差 0.00188
# 误差 0.00187
# 误差 0.00187
# 误差 0.00186
# 误差 0.00186
# 误差 0.00185
# 误差 0.00185
# 误差 0.00185
# 误差 0.00184
# 误差 0.00184
# 误差 0.00183
# 误差 0.00183
# 误差 0.00183
# 误差 0.00182
# 误差 0.00182
# 误差 0.00181
# 误差 0.00181
# 误差 0.00181
# 误差 0.00180
# 误差 0.00180
# 误差 0.00179
# 误差 0.00179
# 误差 0.00179
# 误差 0.00178
# 误差 0.00178
# 误差 0.00177
# 误差 0.00177
# 误差 0.00177
# 误差 0.00176
# 误差 0.00176
# 误差 0.00176
# 误差 0.00175
# 误差 0.00175
# 误差 0.00174
# 误差 0.00174
# 误差 0.00174
# 误差 0.00173
# 误差 0.00173
# 误差 0.00173
# 误差 0.00172
# 误差 0.00172
# 误差 0.00172
# 误差 0.00171
# 误差 0.00171
# 误差 0.00171
# 误差 0.00170
# 误差 0.00170
# 误差 0.00169
# 误差 0.00169
# 误差 0.00169
# 误差 0.00168
# 误差 0.00168
# 误差 0.00168
# 误差 0.00167
# 误差 0.00167
# 误差 0.00167
# 误差 0.00166
# 误差 0.00166
# 误差 0.00166
# 误差 0.00165
# 误差 0.00165
# 误差 0.00165
# 误差 0.00164
# 误差 0.00164
# 误差 0.00164
# 误差 0.00163
# 误差 0.00163
# 误差 0.00163
# 误差 0.00162
# 误差 0.00162
# 误差 0.00162
# 误差 0.00162
# 误差 0.00161
# 误差 0.00161
# 误差 0.00161
# 误差 0.00160
# 误差 0.00160
# 误差 0.00160
# 误差 0.00159
# 误差 0.00159
# 误差 0.00159
# 误差 0.00158
# 误差 0.00158
# 误差 0.00158
# 误差 0.00158
# 误差 0.00157
# 误差 0.00157
# 误差 0.00157
# 误差 0.00156
# 误差 0.00156
# 误差 0.00156
# 误差 0.00155
# 误差 0.00155
# 误差 0.00155
# 误差 0.00155
# 误差 0.00154
# 误差 0.00154
# 误差 0.00154
# 误差 0.00153
# 误差 0.00153
# 误差 0.00153
# 误差 0.00153
# 误差 0.00152
# 误差 0.00152
# 误差 0.00152
# 误差 0.00151
# 误差 0.00151
# 误差 0.00151
# 误差 0.00151
# 误差 0.00150
# 误差 0.00150
# 误差 0.00150
# 误差 0.00150
# 误差 0.00149
# 误差 0.00149
# 误差 0.00149
# 误差 0.00148
# 误差 0.00148
# 误差 0.00148
# 误差 0.00148
# 误差 0.00147
# 误差 0.00147
# 误差 0.00147
# 误差 0.00147
# 误差 0.00146
# 误差 0.00146
# 误差 0.00146
# 误差 0.00146
# 误差 0.00145
# 误差 0.00145
# 误差 0.00145
# 误差 0.00145
# 误差 0.00144
# 误差 0.00144
# 误差 0.00144
# 误差 0.00144
# 误差 0.00143
# 误差 0.00143
# 误差 0.00143
# 误差 0.00143
# 误差 0.00142
# 误差 0.00142
# 误差 0.00142
# 误差 0.00142
# 误差 0.00141
# 误差 0.00141
# 误差 0.00141
# 误差 0.00141
# 误差 0.00140
# 误差 0.00140
# 误差 0.00140
# 误差 0.00140
# 误差 0.00139
# 误差 0.00139
# 误差 0.00139
# 误差 0.00139
# 误差 0.00138
# 误差 0.00138
# 误差 0.00138
# 误差 0.00138
# 误差 0.00138
# 误差 0.00137
# 误差 0.00137
# 误差 0.00137
# 误差 0.00137
# 误差 0.00136
# 误差 0.00136
# 误差 0.00136
# 误差 0.00136
# 误差 0.00136
# 误差 0.00135
# 误差 0.00135
# 误差 0.00135
# 误差 0.00135
# 误差 0.00134
# 误差 0.00134
# 误差 0.00134
# 误差 0.00134
# 误差 0.00134
# 误差 0.00133
# 误差 0.00133
# 误差 0.00133
# 误差 0.00133
# 误差 0.00132
# 误差 0.00132
# 误差 0.00132
# 误差 0.00132
# 误差 0.00132
# 误差 0.00131
# 误差 0.00131
# 误差 0.00131
# 误差 0.00131
# 误差 0.00131
# 误差 0.00130
# 误差 0.00130
# 误差 0.00130
# 误差 0.00130
# 误差 0.00130
# 误差 0.00129
# 误差 0.00129
# 误差 0.00129
# 误差 0.00129
# 误差 0.00129
# 误差 0.00128
# 误差 0.00128
# 误差 0.00128
# 误差 0.00128
# 误差 0.00128
# 误差 0.00127
# 误差 0.00127
# 误差 0.00127
# 误差 0.00127
# 误差 0.00127
# 误差 0.00126
# 误差 0.00126
# 误差 0.00126
# 误差 0.00126
# 误差 0.00126
# 误差 0.00125
# 误差 0.00125
# 误差 0.00125
# 误差 0.00125
# 误差 0.00125
# 误差 0.00124
# 误差 0.00124
# 误差 0.00124
# 误差 0.00124
# 误差 0.00124
# 误差 0.00124
# 误差 0.00123
# 误差 0.00123
# 误差 0.00123
# 误差 0.00123
# 误差 0.00123
# 误差 0.00122
# 误差 0.00122
# 误差 0.00122
# 误差 0.00122
# 误差 0.00122
# 误差 0.00121
# 误差 0.00121
# 误差 0.00121
# 误差 0.00121
# 误差 0.00121
# 误差 0.00121
# 误差 0.00120
# 误差 0.00120
# 误差 0.00120
# 误差 0.00120
# 误差 0.00120
# 误差 0.00120
# 误差 0.00119
# 误差 0.00119
# 误差 0.00119
# 误差 0.00119
# 误差 0.00119
# 误差 0.00119
# 误差 0.00118
# 误差 0.00118
# 误差 0.00118
# 误差 0.00118
# 误差 0.00118
# 误差 0.00117
# 误差 0.00117
# 误差 0.00117
# 误差 0.00117
# 误差 0.00117
# 误差 0.00117
# 误差 0.00116
# 误差 0.00116
# 误差 0.00116
# 误差 0.00116
# 误差 0.00116
# 误差 0.00116
# 误差 0.00116
# 误差 0.00115
# 误差 0.00115
# 误差 0.00115
# 误差 0.00115
# 误差 0.00115
# 误差 0.00115
# 误差 0.00114
# 误差 0.00114
# 误差 0.00114
# 误差 0.00114
# 误差 0.00114
# 误差 0.00114
# 误差 0.00113
# 误差 0.00113
# 误差 0.00113
# 误差 0.00113
# 误差 0.00113
# 误差 0.00113
# 误差 0.00113
# 误差 0.00112
# 误差 0.00112
# 误差 0.00112
# 误差 0.00112
# 误差 0.00112
# 误差 0.00112
# 误差 0.00111
# 误差 0.00111
# 误差 0.00111
# 误差 0.00111
# 误差 0.00111
# 误差 0.00111
# 误差 0.00111
# 误差 0.00110
# 误差 0.00110
# 误差 0.00110
# 误差 0.00110
# 误差 0.00110
# 误差 0.00110
# 误差 0.00109
# 误差 0.00109
# 误差 0.00109
# 误差 0.00109
# 误差 0.00109
# 误差 0.00109
# 误差 0.00109
# 误差 0.00108
# 误差 0.00108
# 误差 0.00108
# 误差 0.00108
# 误差 0.00108
# 误差 0.00108
# 误差 0.00108
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00107
# 误差 0.00106
# 误差 0.00106
# 误差 0.00106
# 误差 0.00106
# 误差 0.00106
# 误差 0.00106
# 误差 0.00106
# 误差 0.00105
# 误差 0.00105
# 误差 0.00105
# 误差 0.00105
# 误差 0.00105
# 误差 0.00105
# 误差 0.00105
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00104
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00103
# 误差 0.00102
# 误差 0.00102
# 误差 0.00102
# 误差 0.00102
# 误差 0.00102
# 误差 0.00102
# 误差 0.00102
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00101
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00100
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00099
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00098
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00097
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00096
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00095
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00094
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00093
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00092
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00091
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00090
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00089
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00088
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00087
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00086
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# 误差 0.00085
# [1, 2, 5] -> [0.002314120739261989]
# [1, 3, 4] -> [0.959520057952757]
# [1, 6, 2] -> [0.9933494252767411]
# [1, 5, 1] -> [0.0007267079196326646]
# [1, 8, 4] -> [0.9999987896093795]
# 输入层权重
# [-0.10334518938428412, 0.012516156580377247, -0.1765521702215198, -0.18669419895669828]
# [0.3615653866205547, -0.03844658706826637, 0.02748649765129807, 0.03078465502140401]
# [-0.42728662521488653, -0.10292395063104864, 0.1696516280788271, 0.040824658970080696]
# [0.16906642797861587, -0.16519757551871775, 0.11869538693720383, -0.027217531458466004]
# 输出层权重
# [8.234557662514711e-16]
# [-19.00859073724328]
# [15.216073197758488]
# [-19.205630931573705]
